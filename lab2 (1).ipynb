# %% [markdown]
# ## Лабоораторная работа №2
# # индивидуальный вариант 16, он же 6-ой

# %%
import pandas as pd

# %%
df = pd.read_csv('6_2games.csv')

# %% [markdown]
# Вывод первых 20 строк датасета

# %%
df.head(20)
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                     Wii Sports      Wii           2006.0
# 1                              Super Mario Bros.      NES           1985.0
# 2                                 Mario Kart Wii      Wii           2008.0
# 3                              Wii Sports Resort      Wii           2009.0
# 4                       Pokemon Red/Pokemon Blue       GB           1996.0
# 5                                         Tetris       GB           1989.0
# 6                          New Super Mario Bros.       DS           2006.0
# 7                                       Wii Play      Wii           2006.0
# 8                      New Super Mario Bros. Wii      Wii           2009.0
# 9                                      Duck Hunt      NES           1984.0
# 10                                    Nintendogs       DS           2005.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
print(df.isna().sum())
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Ознакомившись с именами, принимаем решение привести все названия столбцов к единому регистру

# %%
df = df.rename(columns={"Name": "name","Platform":"platform","Year_of_Release":"year_of_release",
                        "Genre":"genre","NA_sales":"na_sales","EU_sales":"eu_sales",
               "JP_sales":"jp_sales","Other_sales":"other_sales","Critic_Score":"critic_score",
               "User_Score":"user_score","Rating":"rating"})

# %%
df['critic_score'].fillna(df['critic_score'].mean())
df['year_of_release'].fillna(df['year_of_release'].mean())
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16710    2016.0
# 16711    2006.0
# 16712    2016.0
# 16713    2003.0
# 16714    2016.0
# Name: year_of_release, Length: 16715, dtype: float64

# %%
print(df.isna().sum())
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Успешно видим что количество дубликатов равно 0

# %% [markdown]
# # Построение точечной диаграммы

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15))
# Out:
# array([[<AxesSubplot:xlabel='year_of_release', ylabel='year_of_release'>,
#         <AxesSubplot:xlabel='na_sales', ylabel='year_of_release'>,
#         <AxesSubplot:xlabel='eu_sales', ylabel='year_of_release'>,
#         <AxesSubplot:xlabel='jp_sales', ylabel='year_of_release'>,
#         <AxesSubplot:xlabel='other_sales', ylabel='year_of_release'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='year_of_release'>],
#        [<AxesSubplot:xlabel='year_of_release', ylabel='na_sales'>,
#         <AxesSubplot:xlabel='na_sales', ylabel='na_sales'>,
#         <AxesSubplot:xlabel='eu_sales', ylabel='na_sales'>,
#         <AxesSubplot:xlabel='jp_sales', ylabel='na_sales'>,
#         <AxesSubplot:xlabel='other_sales', ylabel='na_sales'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='na_sales'>],
#        [<AxesSubplot:xlabel='year_of_release', ylabel='eu_sales'>,
#         <AxesSubplot:xlabel='na_sales', ylabel='eu_sales'>,
# ...

# %%
df.plot(x="year_of_release", y = "critic_score", kind = "scatter", rot =-25)
# Out:
# <AxesSubplot:xlabel='year_of_release', ylabel='critic_score'>

# %%
df.plot(x="year_of_release", y = "eu_sales", kind = "scatter", alpha = 0.1)
# Out:
# <AxesSubplot:xlabel='year_of_release', ylabel='eu_sales'>

# %%
df.plot(x="year_of_release", y = "na_sales", kind = "scatter", alpha = 0.1)
# Out:
# <AxesSubplot:xlabel='year_of_release', ylabel='na_sales'>

# %%
df[['year_of_release','na_sales','eu_sales','jp_sales','other_sales','critic_score']].cov()
# Out:
#                  year_of_release  na_sales  eu_sales  jp_sales  other_sales  \
# year_of_release        34.539715 -0.444915  0.011845 -0.307815     0.041786
# na_sales               -0.444915  0.661951  0.313418  0.112976     0.097027
# eu_sales                0.011845  0.313418  0.253350  0.067634     0.067934
# jp_sales               -0.307815  0.112976  0.067634  0.095390     0.016788
# other_sales             0.041786  0.097027  0.067934  0.016788     0.034868
# critic_score            0.665457  3.008290  1.955730  0.563781     0.689664
#
#                  critic_score
# year_of_release      0.665457
# na_sales             3.008290
# eu_sales             1.955730
# jp_sales             0.563781
# other_sales          0.689664
# critic_score       194.272431

# %% [markdown]
# # Расчёт коэффициента ковариации и корреляции

# %%
df.cov()
# Out:
#                  year_of_release  na_sales  eu_sales  jp_sales  other_sales  \
# year_of_release        34.539715 -0.444915  0.011845 -0.307815     0.041786
# na_sales               -0.444915  0.661951  0.313418  0.112976     0.097027
# eu_sales                0.011845  0.313418  0.253350  0.067634     0.067934
# jp_sales               -0.307815  0.112976  0.067634  0.095390     0.016788
# other_sales             0.041786  0.097027  0.067934  0.016788     0.034868
# critic_score            0.665457  3.008290  1.955730  0.563781     0.689664
#
#                  critic_score
# year_of_release      0.665457
# na_sales             3.008290
# eu_sales             1.955730
# jp_sales             0.563781
# other_sales          0.689664
# critic_score       194.272431

# %% [markdown]
# Исходя из анализа коэффициентов корреляции между различными категорими, мы приходим к выводу, что наиболее хорошая зависимость прослеживается между critical_score и na_sales. Так как значение коэффициента кореляции положительное, то это говорит о том, что с ростом первой величины растёт вторая.Следовательно, можем преполодить на основе предоставленных данных датасета, что в северной америке более щадящие притекрии и счастливые покупатали игр

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ef9f6_row0_col0, #T_ef9f6_row1_col1, #T_ef9f6_row2_col2, #T_ef9f6_row3_col3, #T_ef9f6_row4_col4, #T_ef9f6_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ef9f6_row0_col1, #T_ef9f6_row0_col2, #T_ef9f6_row0_col3, #T_ef9f6_row0_col4, #T_ef9f6_row0_col5, #T_ef9f6_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ef9f6_row1_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ef9f6_row1_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_ef9f6_row1_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_ef9f6_row1_col4 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_ef9f6_row1_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ef9f6_row2_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ef9f6_row2_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_ef9f6_row2_col3 {
#   background-color: #e1dad6;
# ...

# %% [markdown]
# Исследовать взаимосвязь между переменными с помощью оценки коэффициента корреляции и ковариации. аимосвязь двух или нескольких величин называется «корреляция». Как оценить численно, насколько тесна взаимосвязь? Для этого находят коэффициент корреляции Пирсона. Он помогает определить наличие линейной связи между величинами и принимает значения от -1 до 1. Если с ростом первой величины растёт вторая, то коэффициент корреляции Пирсона — положительный. Если при изменении одной величины другая остаётся прежней, то коэффициент равен 0. Если рост одной величины связан с уменьшением другой, коэффициент отрицательный. Чем ближе коэффициент корреляции Пирсона к крайним значениям 1 или -1, тем теснее линейная взаимосвязь. Если значение близко к нулю, значит, линейная связь слабая либо отсутствует вовсе. Бывает, что коэффициент нулевой не потому, что связи между значениями нет, а из-за того, что у неё более сложный, не линейный характер. Потому-то коэффициент корреляции такую связь не берёт. Коэффициент Пирсона находят методом corr().Если смотреть по получившемуся датасету, в результате выполнения данной команды, самая тесная линейная взаимосвязь между eu_sales и na_sales, а самая слабая между critic_score и year_of_release. Можно сделать вывод что зависимости между оценками и датой релиза почти нет.

# %%
import seaborn
import numpy as np
matrix = np.triu(df.corr())
seaborn.heatmap(df.corr(), annot = True, fmt='.1g', mask = matrix, vmin = -1, vmax = 1, center = 0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Построение тепловой карты корреляции для более качественной визуализации и анализа данных С помощью данной тепловой карты мы можем проверить наши выводы, сделанные на основании данных из предыдущего датасета Тепловая карта корреляции строится с помощью метода heatmap()
